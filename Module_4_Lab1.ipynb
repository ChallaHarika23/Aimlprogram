# %% [markdown]
# <a href="https://colab.research.google.com/github/ChallaHarika23/Aimlprogram/blob/main/Module_4_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
X = np.array([
    [-2, 4, -1],
    [4, 1, -1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],
])

# %%
y = np.array([-1, -1, 1, 1, 1])

# %%
for d, sample in enumerate(X):
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

plt.plot([-3, 6], [6, 0.5])

# %%
def percep_algo(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 15

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]
    return w

# %%
def percepalgo_plot(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w
w=percepalgo_plot(X,y)

# %%
for d, sample in enumerate(X):
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

plt.scatter(2, 2, s=120, marker='_', linewidths=2, color='yellow')
plt.scatter(4, 3, s=120, marker='+', linewidths=2, color='blue')

x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]

x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')

# %% [markdown]
# ## Things to try

# %% [markdown]
# ## 1.Try this on a real dataset like the Sonar dataset or the Banknote Dataset and show the error plot.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load the Banknote Authentication Dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"
column_names = ["Variance", "Skewness", "Curtosis", "Entropy", "Class"]
data = pd.read_csv(url, names=column_names, header=None)


data["Class"] = data["Class"].map({0: -1, 1: 1})

X = data.drop("Class", axis=1).values
y = data["Class"].values

# %%
for d, sample in enumerate(X):
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

plt.plot([-3, 6], [6, 0.5])

# %%
def perceptron_algo(X, Y,eta=1):
    w = np.zeros(len(X[0]))
    epochs = 10

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]
    return w

# %%
def perceptalgo_plot(X, Y,eta=1):
    w = np.zeros(len(X[0]))
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w
w=perceptalgo_plot(X,y)

# %%
for d, sample in enumerate(X):
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)


plt.scatter(2, 2, s=120, marker='_', linewidths=2, color='yellow')
plt.scatter(4, 2, s=120, marker='+', linewidths=2, color='blue')
x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]

x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')

# %% [markdown]
# ## 2.Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?

# %%
import numpy as np
import matplotlib.pyplot as plt

def perceptron_algorithm(X, Y, eta=1, epochs=10):
    w = np.zeros(len(X[0]))

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]
    return w

def perceptalgo_plot(X, Y, eta=1, n=30):
    w = np.zeros(len(X[0]))
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

X = np.array([
    [1, 2, -1],
    [2, 3, -1],
    [3, 1, -1],
    [6, 1, -1],
    [7, 3, -1],
])

y = np.array([-1, -1, -1, 1, 1])

learning_rates = [0.01, 0.1, 1, 10]

for eta in learning_rates:
    w = perceptalgo_plot(X, y, eta=eta)
    plt.title(f'Perceptron Convergence with Learning Rate {eta}')
    plt.show()

# %% [markdown]
# You can observe how the total loss changes over epochs for each learning rate. Adjusting the learning rate will affect the convergence behavior, and too high a learning rate might prevent convergence, while too low a learning rate might result in slow convergence.

# %% [markdown]
# ### 3.Take a toy dataset that is not linearly separable and run the perceptron algorithm on it. What happens? Note your observations. An example is given below.

# %%
X = np.array([
    [1, 2, -1],
    [2, 3, -1],
    [3, 1, -1],
    [6, 1, -1],
    [7, 3, -1],
])

y = np.array([-1, -1, -1, 1, 1])

# %%
print(percepalgo_plot(X, y))
# Out:
# [ 7. -9. 13.]

# %% [markdown]
# You will observe that the algorithm fails to find a linear decision boundary that perfectly separates the two classes, and the number of errors may not decrease over time. This is a characteristic behavior of the perceptron algorithm when dealing with non-linearly separable datasets
